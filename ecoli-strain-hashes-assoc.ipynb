# %%
# %matplotlib inline
import pylab
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
import palettable as pal
import pandas as pd
from scipy.cluster.hierarchy import dendrogram
import collections

# %%
import sys
sys.path.insert(0, '/Users/t/dev/sourmash')
import sourmash_lib
import sourmash_lib.fig
import sourmash_lib.signature

# %% [markdown]
# # Build hash association matrix
#
# Run:
# ```
# ./hashes-to-association.py --threshold=2 -o ecoli-assoc ecoli_many_sigs/*.sig
# ```

# %% [markdown]
# # Plot k-mer (hash) co-occurrence matrix

# %%
mat, labels = sourmash_lib.fig.load_matrix_and_labels('ecoli-assoc')
_ = sourmash_lib.fig.plot_composite_matrix(mat, labels, show_labels=False, show_indices=False,
                                           vmax=0.1)
